# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
import pandas as pd
import os
from sklearn import preprocessing
# %matplotlib inline

# %%
#Sale data
sale2018 = pd.read_csv("/home/techfield/class/Presentations/Housing_Project1/Sale2018.csv")
sale2017 = pd.read_csv("/home/techfield/class/Presentations/Housing_Project1/Sale2017.csv")
sale2016 = pd.read_csv("/home/techfield/class/Presentations/Housing_Project1/Sale2016.csv")

# %%
#Infomation
res2018 = pd.read_csv("/home/techfield/class/Presentations/Housing_Project1/Residential18.csv")
res2017 = pd.read_csv("/home/techfield/class/Presentations/Housing_Project1/Residential17.csv")
res2016 = pd.read_csv("/home/techfield/class/Presentations/Housing_Project1/Residential16.csv")
# Out:
# /home/techfield/.local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
record = pd.read_csv("/home/techfield/class/Presentations/Housing_Project1/Records.csv")

# %%
record = record.drop(['Short Notes'], axis =1)
record = record.drop(['Unnamed: 6'],axis =1)

# %%
record = record[ (record.Status != "Final" ) & (record.Status != "Issued") & (record.Status != "C of O" ) ]
#record = record[ (record.Project != "Commercial Building Addition")]
#record = record[  (record.Type != "Commercial")]

# %%
records = record["Record Number"].str[5:]

# %%
record["Record Number"] = records

# %%
record.Status.unique()

#C of O, Issued, and Final being taken off
# Out:
# array(['Deficient', 'Approved', 'Request for Corrections', 'Void',
#        'In Review', 'Withdrawn', 'Review Not Required', 'Submitted',
#        'Application Expired', 'Permit Expired', 'Denied'], dtype=object)

# %%
record
# Out:
#             Date Record Number      Record Type  \
# 1     12/31/2018         09020  Building Permit
# 3     12/31/2018         09017  Building Permit
# 4     12/31/2018         09016  Building Permit
# 6     12/31/2018         09012  Building Permit
# 7     12/31/2018         09011  Building Permit
# 9     12/31/2018         09009  Building Permit
# 14    12/31/2018         08996  Building Permit
# 15    12/31/2018         08994  Building Permit
# 16    12/28/2018         08989  Building Permit
# 18    12/28/2018         08987  Building Permit
# 26    12/28/2018         08971  Building Permit
# 28    12/28/2018         08969  Building Permit
# 29    12/28/2018         08968  Building Permit
# 31    12/28/2018         08963  Building Permit
# 32    12/28/2018         08962  Building Permit
# 33    12/28/2018         08961  Building Permit
# 34    12/27/2018         08959  Building Permit
# 35    12/27/2018         08958  Building Permit
# 36    12/27/2018         08956  Building Permit
# 37    12/27/2018         08955  Building Permit
# 38    12/27/2018         08953  Building Permit
# 40    12/27/2018         08950  Building Permit
# 41    12/27/2018         08945  Building Permit
# 43    12/27/2018         08934  Building Permit
# 45    12/27/2018         08929  Building Permit
# 57    12/21/2018         08894  Building Permit
# 59    12/21/2018         08892  Building Permit
# 60    12/21/2018         08891  Building Permit
# 61    12/21/2018         08890  Building Permit
# 62    12/21/2018         08888  Building Permit
# ...          ...           ...              ...
# 8293  02/02/2016         00693  Building Permit
# 8302  01/29/2016         00642  Building Permit
# 8304  01/29/2016         00631  Building Permit
# 8311  01/28/2016         00611  Building Permit
# 8317  01/27/2016         00601  Building Permit
# 8330  01/26/2016         00543  Building Permit
# 8334  01/25/2016         00536  Building Permit
# 8337  01/25/2016         00525  Building Permit
# 8338  01/25/2016         00523  Building Permit
# 8345  01/25/2016         00502  Building Permit
# 8349  01/22/2016         00484  Building Permit
# 8356  01/21/2016         00449  Building Permit
# 8366  01/21/2016         00420  Building Permit
# 8374  01/20/2016         00401  Building Permit
# 8383  01/19/2016         00367  Building Permit
# 8386  01/19/2016         00363  Building Permit
# 8387  01/19/2016         00362  Building Permit
# 8397  01/15/2016         00325  Building Permit
# 8399  01/14/2016         00321  Building Permit
# 8404  01/14/2016         00296  Building Permit
# 8405  01/13/2016         00293  Building Permit
# 8413  01/13/2016         00276  Building Permit
# 8421  01/12/2016         00237  Building Permit
# 8424  01/12/2016         00234  Building Permit
# 8431  01/12/2016         00205  Building Permit
# 8432  01/12/2016         00203  Building Permit
# 8443  01/11/2016         00182  Building Permit
# 8444  01/11/2016         00175  Building Permit
# 8455  01/06/2016         00121  Building Permit
# 8473  01/05/2016         00046  Building Permit
#
#                                            Project Name  \
# 1                           Single Family Residence New
# 3                      Single Family Residence Addition
# 4                      Single Family Residence Addition
# 6                      Single Family Residence Addition
# 7                      Single Family Residence Addition
# 9                      Single Family Residence Addition
# 14                          Single Family Residence New
# 15                     Single Family Residence Addition
# 16                     Single Family Residence Addition
# 18                            Commercial Building Other
# 26                          Single Family Residence New
# 28                     Single Family Residence Addition
# 29                         Commercial Building Addition
# 31                     Single Family Residence Addition
# 32                            Commercial Building Other
# 33                          Single Family Residence New
# 34                            Commercial Building Other
# 35                         Commercial Building Addition
# 36                         Commercial Building Addition
# 37                         Commercial Building Addition
# 38                         Commercial Building Addition
# 40                         Commercial Building Addition
# 41                                   Tenant Improvement
# 43                     Single Family Residence Addition
# 45                          Single Family Residence New
# 57                          Single Family Residence New
# 59                          Single Family Residence New
# 60                         Commercial Building Addition
# 61                         Commercial Building Addition
# 62                         Commercial Building Addition
# ...                                                 ...
# 8293                   Single Family Residence Addition
# 8302                          Commercial Building Other
# 8304                          Commercial Building Other
# 8311                   Single Family Residence Addition
# 8317                   Single Family Residence Addition
# 8330                   Single Family Residence Addition
# 8334                 Single Family Residence Alteration
# 8337                        Single Family Residence New
# 8338                        Single Family Residence New
# 8345                          Commercial Building Other
# 8349                   Single Family Residence Addition
# 8356                   Single Family Residence Addition
# 8366                 Single Family Residence Alteration
# 8374                        Single Family Residence New
# 8383                 Single Family Residence Alteration
# 8386                   Single Family Residence Addition
# 8387                   Single Family Residence Addition
# 8397                   Single Family Residence Addition
# 8399                            Commercial Building New
# 8404                       Commercial Building Addition
# 8405                   Single Family Residence Addition
# 8413                     Commercial Building Alteration
# 8421                   Single Family Residence Addition
# 8424                   Single Family Residence Addition
# 8431                          Commercial Building Other
# 8432    Single Family Residence Addition - COMBO/SNEW -
# 8443                   Single Family Residence Addition
# 8444                   Single Family Residence Addition
# 8455  Single Family Residence Addition - Permit Rene...
# 8473                     Commercial Building Alteration
#
#                        Status
# 1                   Deficient
# 3                   Deficient
# 4                    Approved
# 6                   Deficient
# 7     Request for Corrections
# 9                    Approved
# 14                  Deficient
# 15                   Approved
# 16    Request for Corrections
# 18                   Approved
# 26                  Deficient
# 28                   Approved
# 29    Request for Corrections
# 31                   Approved
# 32                       Void
# 33                   Approved
# 34    Request for Corrections
# 35    Request for Corrections
# 36    Request for Corrections
# 37    Request for Corrections
# 38    Request for Corrections
# 40                       Void
# 41    Request for Corrections
# 43                   Approved
# 45    Request for Corrections
# 57                   Approved
# 59                   Approved
# 60                  In Review
# 61                  In Review
# 62                  In Review
# ...                       ...
# 8293      Application Expired
# 8302           Permit Expired
# 8304      Application Expired
# 8311           Permit Expired
# 8317           Permit Expired
# 8330           Permit Expired
# 8334                     Void
# 8337                Withdrawn
# 8338                Withdrawn
# 8345      Application Expired
# 8349           Permit Expired
# 8356           Permit Expired
# 8366           Permit Expired
# 8374                Withdrawn
# 8383           Permit Expired
# 8386           Permit Expired
# 8387  Request for Corrections
# 8397      Application Expired
# 8399      Application Expired
# 8404                     Void
# 8405           Permit Expired
# 8413           Permit Expired
# 8421      Application Expired
# 8424           Permit Expired
# 8431           Permit Expired
# 8432           Permit Expired
# 8443           Permit Expired
# 8444      Application Expired
# 8455           Permit Expired
# 8473                Withdrawn
#
# [1317 rows x 5 columns]

# %%
res2017.shape

# %%
#Appended the 3 sale matricies


middle = sale2018.append(sale2017)
combo_sale = middle.append(sale2016)

combo_sale.shape

#shape (83070, 14)

# %%
#Appended the 3 residential matricies

middleres = res2018.append(res2017)
combo_res = middleres.append(res2016)

combo_res.shape

#shape (861696, 32)

# %%
#Merge the 2 data frames

big = pd.merge(combo_sale,combo_res, how = 'inner', left_on = "Parcel", right_on = "PARCEL")
big.shape

#size (169689, 46)

# %%
big.dtypes

# %%
bigger = pd.merge(big,records, how = "inner", left_on = "APPLICATION", right_on = "Record")

# %%
#Getting Sale date into a workable form

big_string=big.SaleDate.astype(str)
big4=big_string.str[0:4]
SaleDate = big4.astype(int)

# %%
#Putting it back in the dataframe

SaleDate
big['SaleDate'] = SaleDate

# %%
#Deleting the duplicate rows

smaller=[]

smaller = big[big['SaleDate'] == big['TAXYEAR']]

# %%
#Getting index back in order

smaller = smaller.reset_index()

# %%
#Removing houses that weren't single family houses

smaller = smaller[smaller.SFRCONDO !='C']

# %%
#Deleting trash

smaller=smaller.drop("index",axis =1)
smaller=smaller.drop("Parcel",axis=1)
smaller=smaller.drop("SequenceNum",axis=1)
smaller = smaller.drop("PropertyType",axis=1)
smaller = smaller.drop("RecordingDate",axis=1)
smaller = smaller.drop("TAXYEAR",axis=1)
smaller = smaller.drop("PARCEL",axis=1)
smaller = smaller.drop("SFRCONDO",axis=1)
smaller = smaller.drop("INSPECTION",axis=1)
smaller = smaller.drop("LASTACTION",axis=1)
smaller = smaller.drop("VALUATIONC",axis=1)
smaller = smaller.drop("APPLICATION",axis=1)
smaller = smaller.drop("APPRAISER",axis=1)
smaller = smaller.drop("PHONE",axis=1)
smaller = smaller.drop("COMPLEXID",axis=1)

# %%
smaller.shape

#Our full datafame before onehotting. size "(45736, 32)"

# %%
final=pd.get_dummies(smaller,columns=["SaleDate","IntendedUse","Financing","Deed","ValidationDescription","BuyerSellerRelated","Solar","PersonalProperty","PartialInterest","CLASS","QUALITY","WALLS","ROOF","HEAT","COOL","PATIO","PATIONUMBE","CONDITION","GARAGE"])

#One-hotted categorical data

# %%
final.shape

# %%
final = final[final.SalePrice != "Unknown"]

final.SalePrice = final.SalePrice.astype('int64')

# %%
#Normalize weights

max1 = max(final.SalePrice)
final.SalePrice=final['SalePrice']/ max1
max1 = max(final.STORIES)
final.STORIES=final['STORIES'] / max1
max1 = max(final.SQFT)
final.SQFT=final['SQFT'] / max1
max1 = max(final.YEAR)
final.YEAR=final['YEAR'] / max1
max1 = max(final.POOLAREA)
final.POOLAREA=final['POOLAREA'] / max1
max1 = max(final.MAIN)
final.MAIN=final['MAIN'] / max1
max1 = max(final.CONTROL)
final.CONTROL=final['CONTROL'] / max1
max1 = max(final.ACTUAL)
final.ACTUAL=final['ACTUAL'] / max1
max1 = max(final.ROOMS)
final.ROOMS=final['ROOMS'] / max1
max1 = max(final.BATHFIXTUR)
final.BATHFIXTUR=final['BATHFIXTUR'] / max1

final

# %%
seed=4

# %%
#final.to_csv(r'/home/techfield/class\Final_Sales2.csv')

# %%
#Time to split data into training, validation and test sets
#First, get a taining set

train=final.sample(frac=.6,random_state = seed)
train_no_y = train.drop("SalePrice",axis=1)

# %%
#train.to_csv(r'/home/techfield/class\train_Sales.csv')

# %%
#We have to pull the numbers out that weren't trained on

validate_test = final.loc[~final.index.isin(train.index)]
validate_test.shape

# %%
#Next, we come up with our validation set and pull use the leftover rows as our test set

validate = validate_test.sample(frac=.5,random_state = seed )
validate_no_y = validate.drop("SalePrice",axis=1)
test = validate_test.loc[~validate_test.index.isin(validate.index)]
test_no_y = test.drop("SalePrice",axis=1)

#test.shape

# Shape is 9145 x 170

# %%
X = np.column_stack((np.ones((27435,1)),train_no_y)) #27435 x 170 Matrix
y = np.array(train.SalePrice) #27435

# %%
def OLS(y, y_hat):
    return (y - y_hat).dot(y - y_hat)
def R2(y, y_hat):
    return 1 - (y - y_hat).dot(y - y_hat) / (y - y.mean()).dot(y - y.mean())

# %%
w = np.random.randn(130)

J = []
eta = 1e-14
epochs = 10000

for t in range(epochs):
    y_hat = X.dot(w)
    J.append(OLS(y, y_hat))
    w -= eta*X.T.dot(y_hat - y)
    
plt.figure()
plt.plot(J)

# %%
1 - (y - y_hat).dot(y - y_hat) / (y - y.mean()).dot(y - y.mean())

#-65578.638.......... Well that can't be right

# %% [markdown]
# #Once we have w, we can apply it to the validate X's to try to find a good R^2 for the set.
# #After tuning the hyperparameters by using elastic net reggression, we would come up with a workable result
# #We would then present the test set findings.
#
# #...... I would do that, if I could figure out why this won't give me a decent R2.

# %%
a = '567869876454'
b = a[-5:]
b
